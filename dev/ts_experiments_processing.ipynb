# %%
import os
import json
import math
import pandas as pd
import numpy as np
from typing import List, Dict, Tuple, Optional
from darts import TimeSeries
from darts.models import RNNModel
from darts.dataprocessing.transformers import Scaler
from darts.metrics import mae, mape, rmse
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
def build_monthly_features(bank_df: pd.DataFrame) -> pd.DataFrame:
    """Build monthly cashflow and balance features from bank transactions."""
    
    df = bank_df.copy()
    
    # Handle date column - could be index or column
    if 'date' in df.columns:
        df['date'] = pd.to_datetime(df['date'])
    elif df.index.name == 'date' or isinstance(df.index, pd.DatetimeIndex):
        df = df.reset_index()
        if 'date' not in df.columns:
            df.rename(columns={df.columns[0]: 'date'}, inplace=True)
        df['date'] = pd.to_datetime(df['date'])
    else:
        raise ValueError("No date column or datetime index found in dataframe")
    
    # Ensure required columns exist
    required_cols = ['income', 'expense']
    if not all(col in df.columns for col in required_cols):
        raise ValueError(f"Bank dataframe must contain columns: {required_cols}")
    
    # Convert to numeric, handling any non-numeric values
    df['income'] = pd.to_numeric(df['income'], errors='coerce').fillna(0)
    df['expense'] = pd.to_numeric(df['expense'], errors='coerce').fillna(0)
    
    # Create monthly aggregations
    df['month'] = df['date'].dt.to_period('M')
    
    monthly_agg = df.groupby('month').agg({
        'income': 'sum',
        'expense': 'sum'
    }).reset_index()
    
    # Calculate derived features
    monthly_agg['net_cashflow'] = monthly_agg['income'] - monthly_agg['expense']
    monthly_agg['balance'] = monthly_agg['net_cashflow'].cumsum()
    
    # Convert period to timestamp for compatibility with Darts
    monthly_agg['date'] = monthly_agg['month'].dt.to_timestamp('M')  # End of month
    monthly_agg = monthly_agg.set_index('date')
    
    # Fill missing months with zeros if needed
    if len(monthly_agg) > 1:
        full_idx = pd.date_range(
            start=monthly_agg.index.min(), 
            end=monthly_agg.index.max(), 
            freq='ME'  # Month end
        )
        monthly_agg = monthly_agg.reindex(full_idx, fill_value=0.0)
        # Recalculate balance after filling gaps
        monthly_agg['balance'] = monthly_agg['net_cashflow'].cumsum()
    
    return monthly_agg[['net_cashflow', 'balance']]

def load_user_data(base_dir: str, user_id: str) -> pd.DataFrame:
    """Load and combine bank and card data for a user."""
    
    bank_file = os.path.join(base_dir, f"bank_user_{user_id}.csv")
    card_file = os.path.join(base_dir, f"card_user_{user_id}.csv")
    
    frames = []
    
    # Load bank data
    if os.path.exists(bank_file):
        bank_df = pd.read_csv(bank_file)
        frames.append(bank_df)
    
    # Load card data if available
    if os.path.exists(card_file):
        card_df = pd.read_csv(card_file)
        frames.append(card_df)
    
    if not frames:
        raise FileNotFoundError(f"No data files found for user {user_id}")
    
    # Combine all data
    combined_df = pd.concat(frames, ignore_index=True)
    return combined_df


def generate_synthetic_data(real_data: pd.DataFrame, n_months: int = 24, noise_level: float = 0.1) -> pd.DataFrame:
    """Generate synthetic data by extending patterns from real data."""
    
    if len(real_data) < 2:
        raise ValueError("Need at least 2 months of real data to generate synthetic data")
    
    # Calculate growth trends and seasonality
    cashflow_trend = real_data['net_cashflow'].diff().mean()
    balance_trend = real_data['balance'].diff().mean()
    
    # Base statistics for noise generation
    cf_std = real_data['net_cashflow'].std()
    bal_std = real_data['balance'].std()
    
    # Generate future dates
    start_date = real_data.index[-1] + pd.DateOffset(months=1)
    future_dates = pd.date_range(start=start_date, periods=n_months, freq='ME')
    
    # Initialize synthetic data
    synthetic_data = []
    last_balance = real_data['balance'].iloc[-1]
    
    np.random.seed(42)  # For reproducibility
    
    for i, date in enumerate(future_dates):
        # Add trend and seasonal patterns
        seasonal_factor = 1 + 0.1 * np.sin(2 * np.pi * i / 12)  # Annual seasonality
        
        # Generate cashflow with trend and noise
        base_cf = real_data['net_cashflow'].mean() + (cashflow_trend * i)
        noise_cf = np.random.normal(0, noise_level * cf_std)
        net_cashflow = (base_cf * seasonal_factor) + noise_cf
        
        # Update balance
        last_balance += net_cashflow
        noise_bal = np.random.normal(0, noise_level * bal_std * 0.1)  # Smaller noise for balance
        balance = last_balance + noise_bal
        
        synthetic_data.append({
            'net_cashflow': net_cashflow,
            'balance': balance
        })
    
    synthetic_df = pd.DataFrame(synthetic_data, index=future_dates)
    return synthetic_df


def build_datasets(data_dir: str, holdout_frac: float = 0.1, min_months: int = 3, seed: int = 42):
    """Build training and testing datasets."""
    
    # Generate user IDs
    user_ids = [f"{i:04d}" for i in range(1, 1001)]
    
    # Split users into seen/unseen
    np.random.seed(seed)
    n_unseen = max(1, int(len(user_ids) * holdout_frac))
    unseen_users = set(np.random.choice(user_ids, size=n_unseen, replace=False))
    seen_users = [uid for uid in user_ids if uid not in unseen_users]
    
    datasets = {
        'seen_users': seen_users,
        'unseen_users': sorted(list(unseen_users)),
        'real_series': {'seen': [], 'unseen': []},
        'synthetic_series': {'seen': []},
        'train_series': [],
        'test_series': {'seen': [], 'unseen': []}
    }
    
    valid_users = {'seen': [], 'unseen': []}
    
    for user_id in user_ids:
        try:
            # Load user data
            user_data = load_user_data(data_dir, user_id)
            monthly_features = build_monthly_features(user_data)
            
            # Skip users with insufficient data
            if len(monthly_features) < min_months:
                continue
                
            # Limit to first 3 months for consistency
            monthly_features = monthly_features.head(3)
            # Create TimeSeries for both features
            ts_data = TimeSeries.from_dataframe(
                monthly_features.reset_index(), 
                time_col='date',
                value_cols=['net_cashflow', 'balance']
            )
            
            user_type = 'seen' if user_id in seen_users else 'unseen'
            datasets['real_series'][user_type].append(ts_data)
            valid_users[user_type].append(user_id)
            
            # Generate synthetic data for seen users
            if user_type == 'seen':
                synthetic_monthly = generate_synthetic_data(monthly_features, n_months=24)
                # Combine real and synthetic
                extended_data = pd.concat([monthly_features, synthetic_monthly])
                ts_synthetic = TimeSeries.from_dataframe(
                    extended_data.reset_index(),
                    time_col='date', 
                    value_cols=['net_cashflow', 'balance']
                )
                datasets['synthetic_series']['seen'].append(ts_synthetic)
                datasets['train_series'].append(ts_synthetic)
            
            # Prepare test series (first 2 months for prediction)
            if len(ts_data) >= 2:
                datasets['test_series'][user_type].append(ts_data[:2])
                
        except Exception as e:
            print(f"Warning: Skipping user {user_id} due to error: {e}")
            continue
    
    # Update user lists to only include valid users
    datasets['seen_users'] = valid_users['seen']
    datasets['unseen_users'] = valid_users['unseen']
    
    print(f"Valid users: seen={len(datasets['seen_users'])}, unseen={len(datasets['unseen_users'])}")
    print(f"Training series: {len(datasets['train_series'])}")
    
    return datasets


def train_forecasting_model(train_series: List[TimeSeries], 
                          input_chunk_length: int = 12,
                          output_chunk_length: int = 6,
                          epochs: int = 100,
                          seed: int = 42) -> RNNModel:
    """Train a multi-variate RNN model for cashflow and balance forecasting."""
    
    model = RNNModel(
        model="LSTM",
        hidden_dim=128,
        n_rnn_layers=3,
        dropout=0.2,
        batch_size=32,
        n_epochs=epochs,
        optimizer_kwargs={"lr": 1e-3},
        model_name="CashflowBalanceForecaster",
        random_state=seed,
        input_chunk_length=input_chunk_length,
        output_chunk_length=output_chunk_length,
        force_reset=True,
        save_checkpoints=True
    )
    
    print(f"Training model on {len(train_series)} series...")
    model.fit(train_series, verbose=True)
    
    return model


def evaluate_forecasts(model: RNNModel, 
                      test_series: List[TimeSeries], 
                      actual_series: List[TimeSeries],
                      horizons: List[int] = [3, 6, 12, 24]) -> Dict:
    """Evaluate forecasting performance across multiple horizons."""
    
    results = {}
    
    for horizon in horizons:
        predictions = []
        actuals = []
        
        for test_ts, actual_ts in zip(test_series, actual_series):
            try:
                # Make prediction
                pred = model.predict(n=horizon, series=test_ts, num_samples=1)
                
                # Get actual values (limited to available data)
                actual_len = min(horizon, len(actual_ts) - len(test_ts))
                if actual_len > 0:
                    actual_subset = actual_ts[len(test_ts):len(test_ts) + actual_len]
                    pred_subset = pred[:actual_len]
                    
                    predictions.append(pred_subset)
                    actuals.append(actual_subset)
                    
            except Exception as e:
                print(f"Warning: Prediction failed for horizon {horizon}: {e}")
                continue
        
        if predictions and actuals:
            # Calculate metrics for each component
            metrics = {}
            for i, component in enumerate(['net_cashflow', 'balance']):
                try:
                    pred_component = [p.univariate_component(i) for p in predictions]
                    actual_component = [a.univariate_component(i) for a in actuals]
                    
                    metrics[f'{component}_MAE'] = np.mean([
                        mae(actual, pred) for actual, pred in zip(actual_component, pred_component)
                    ])
                    metrics[f'{component}_MAPE'] = np.mean([
                        mape(actual, pred) for actual, pred in zip(actual_component, pred_component)
                    ])
                    metrics[f'{component}_RMSE'] = np.mean([
                        rmse(actual, pred) for actual, pred in zip(actual_component, pred_component)
                    ])
                except Exception as e:
                    print(f"Warning: Metric calculation failed for {component}: {e}")
                    metrics[f'{component}_MAE'] = float('nan')
                    metrics[f'{component}_MAPE'] = float('nan')
                    metrics[f'{component}_RMSE'] = float('nan')
            
            results[f'horizon_{horizon}'] = metrics
        else:
            results[f'horizon_{horizon}'] = {
                'net_cashflow_MAE': float('nan'),
                'net_cashflow_MAPE': float('nan'),
                'net_cashflow_RMSE': float('nan'),
                'balance_MAE': float('nan'),
                'balance_MAPE': float('nan'),
                'balance_RMSE': float('nan')
            }
    
    return results


def save_forecasts(model: RNNModel, 
                   test_series: List[TimeSeries], 
                   user_ids: List[str],
                   horizons: List[int],
                   output_dir: str):
    """Generate and save forecasts for all horizons."""
    
    os.makedirs(output_dir, exist_ok=True)
    
    for horizon in horizons:
        all_forecasts = []
        
        for i, (test_ts, user_id) in enumerate(zip(test_series, user_ids)):
            try:
                forecast = model.predict(n=horizon, series=test_ts, num_samples=1)
                
                # Convert to dataframe
                forecast_df = forecast.pd_dataframe().reset_index()
                forecast_df['user_id'] = user_id
                forecast_df['horizon'] = horizon
                
                all_forecasts.append(forecast_df)
                
            except Exception as e:
                print(f"Warning: Failed to generate forecast for user {user_id}, horizon {horizon}: {e}")
                continue
        
        if all_forecasts:
            combined_forecasts = pd.concat(all_forecasts, ignore_index=True)
            output_file = os.path.join(output_dir, f'forecasts_horizon_{horizon}.csv')
            combined_forecasts.to_csv(output_file, index=False)
            print(f"Saved forecasts for horizon {horizon} to {output_file}")

# %%
def main():
    """Main pipeline execution."""
    
    # Configuration
    DATA_DIR = "./data/synthetic_users/"
    OUTPUT_DIR = "./results/outputs/"
    HORIZONS = [3, 6, 12, 24]
    
    print("=== Cashflow & Balance Forecasting Pipeline ===")
    
    # Build datasets
    print("\n1. Building datasets...")
    datasets = build_datasets(DATA_DIR, holdout_frac=0.1, min_months=3, seed=42)
    
    if not datasets['train_series']:
        raise RuntimeError("No valid training data found")
    
    # Scale the data
    print("\n2. Scaling data...")
    scaler = Scaler()
    
    # Fit scaler on real seen data only
    real_seen = datasets['real_series']['seen']
    if real_seen:
        scaler.fit(real_seen)
        
        # Transform all series
        train_series_scaled = scaler.transform(datasets['train_series'])
        test_seen_scaled = scaler.transform(datasets['test_series']['seen'])
        test_unseen_scaled = scaler.transform(datasets['test_series']['unseen'])
        real_seen_scaled = scaler.transform(real_seen)
        real_unseen_scaled = scaler.transform(datasets['real_series']['unseen'])
    else:
        raise RuntimeError("No real seen data available for scaling")
    
    # Train model
    print("\n3. Training forecasting model...")
    model = train_forecasting_model(
        train_series_scaled,
        input_chunk_length=6,  # Use 6 months of history
        output_chunk_length=3,  # Predict 3 months ahead
        epochs=50,
        seed=42
    )
    
    # Evaluate on seen users
    print("\n4. Evaluating on seen users...")
    metrics_seen = evaluate_forecasts(
        model, test_seen_scaled, real_seen_scaled, horizons=HORIZONS
    )
    
    # Evaluate on unseen users
    print("\n5. Evaluating on unseen users...")
    metrics_unseen = evaluate_forecasts(
        model, test_unseen_scaled, real_unseen_scaled, horizons=HORIZONS
    )
    
    # Save results
    print("\n6. Saving results...")
    os.makedirs(OUTPUT_DIR, exist_ok=True)
    
    results = {
        'dataset_info': {
            'n_seen_users': len(datasets['seen_users']),
            'n_unseen_users': len(datasets['unseen_users']),
            'n_training_series': len(datasets['train_series'])
        },
        'metrics': {
            'seen_users': metrics_seen,
            'unseen_users': metrics_unseen
        },
        'horizons': HORIZONS
    }
    
    with open(os.path.join(OUTPUT_DIR, 'evaluation_results.json'), 'w') as f:
        json.dump(results, f, indent=2)
    
    # Generate and save forecasts
    print("\n7. Generating forecasts...")
    save_forecasts(
        model, 
        test_seen_scaled,
        datasets['seen_users'][:len(test_seen_scaled)], 
        HORIZONS, 
        OUTPUT_DIR
    )
    
    # Save user lists
    with open(os.path.join(OUTPUT_DIR, 'seen_users.json'), 'w') as f:
        json.dump(datasets['seen_users'], f, indent=2)
    
    with open(os.path.join(OUTPUT_DIR, 'unseen_users.json'), 'w') as f:
        json.dump(datasets['unseen_users'], f, indent=2)
    
    print(f"\n=== Pipeline Complete ===")
    print(f"Results saved to: {OUTPUT_DIR}")
    print(f"Seen users performance: {len(datasets['seen_users'])} users")
    print(f"Unseen users performance: {len(datasets['unseen_users'])} users")
    
    # Print summary metrics
    print(f"\nSample Metrics (Horizon 3):")
    if 'horizon_3' in metrics_seen:
        seen_h3 = metrics_seen['horizon_3']
        print(f"Seen Users - Cashflow MAE: {seen_h3.get('net_cashflow_MAE', 'N/A'):.2f}")
        print(f"Seen Users - Balance MAE: {seen_h3.get('balance_MAE', 'N/A'):.2f}")
    
    if 'horizon_3' in metrics_unseen:
        unseen_h3 = metrics_unseen['horizon_3']
        print(f"Unseen Users - Cashflow MAE: {unseen_h3.get('net_cashflow_MAE', 'N/A'):.2f}")
        print(f"Unseen Users - Balance MAE: {unseen_h3.get('balance_MAE', 'N/A'):.2f}")

# %%
if __name__ == '__main__':
    main()
# Out:
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# === Cashflow & Balance Forecasting Pipeline ===
#
# 1. Building datasets...
#             net_cashflow  balance
# 2023-01-31       -743.54  -743.54
# 2023-02-28       -648.49 -1392.03
# 2023-03-31       -303.61 -1695.64
# Warning: Skipping user 0001 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       3965.11  3965.11
# 2023-02-28       1179.58  5144.69
# 2023-03-31       3042.82  8187.51
# Warning: Skipping user 0002 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       2172.07  2172.07
# 2023-02-28       1872.67  4044.74
# 2023-03-31       1967.48  6012.22
# Warning: Skipping user 0003 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31        509.13   509.13
# 2023-02-28        604.27  1113.40
# 2023-03-31        512.39  1625.79
# Warning: Skipping user 0004 due to error: time_col='date' is not present.
#             net_cashflow   balance
# 2023-01-31       3634.27   3634.27
# 2023-02-28       3843.01   7477.28
# 2023-03-31       4461.47  11938.75
# Warning: Skipping user 0005 due to error: time_col='date' is not present.
#             net_cashflow   balance
# 2023-01-31       5044.76   5044.76
# 2023-02-28       3121.03   8165.79
# 2023-03-31       4267.80  12433.59
# Warning: Skipping user 0006 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       2893.23  2893.23
# 2023-02-28       3496.24  6389.47
# 2023-03-31       2643.17  9032.64
# Warning: Skipping user 0007 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31        313.41   313.41
# 2023-02-28        970.37  1283.78
# 2023-03-31        677.45  1961.23
# Warning: Skipping user 0008 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       2324.92  2324.92
# 2023-02-28       2961.26  5286.18
# 2023-03-31       1233.37  6519.55
# Warning: Skipping user 0009 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       3457.64  3457.64
# 2023-02-28       2286.70  5744.34
# 2023-03-31       1117.85  6862.19
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# Warning: Skipping user 0010 due to error: time_col='date' is not present.
#             net_cashflow   balance
# 2023-01-31       3807.83   3807.83
# 2023-02-28       4228.01   8035.84
# 2023-03-31       3160.24  11196.08
# Warning: Skipping user 0011 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31        958.23   958.23
# 2023-02-28        658.69  1616.92
# 2023-03-31        149.29  1766.21
# Warning: Skipping user 0012 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       1600.26  1600.26
# 2023-02-28        110.29  1710.55
# 2023-03-31        128.69  1839.24
# Warning: Skipping user 0013 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31        263.55   263.55
# 2023-02-28        309.56   573.11
# 2023-03-31        998.38  1571.49
# Warning: Skipping user 0014 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       2794.06  2794.06
# 2023-02-28       2151.17  4945.23
# 2023-03-31       2223.44  7168.67
# Warning: Skipping user 0015 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       1217.21  1217.21
# 2023-02-28       2974.48  4191.69
# 2023-03-31       2321.27  6512.96
# Warning: Skipping user 0016 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       2033.40  2033.40
# 2023-02-28       1726.83  3760.23
# 2023-03-31      -1069.88  2690.35
# Warning: Skipping user 0017 due to error: time_col='date' is not present.
#             net_cashflow   balance
# 2023-01-31       3025.68   3025.68
# 2023-02-28       2620.65   5646.33
# 2023-03-31       4677.10  10323.43
# Warning: Skipping user 0018 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31        -65.69   -65.69
# 2023-02-28        511.50   445.81
# 2023-03-31        328.90   774.71
# Warning: Skipping user 0019 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       1190.20  1190.20
# 2023-02-28       1341.04  2531.24
# 2023-03-31       1602.54  4133.78
# Warning: Skipping user 0020 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31        790.96   790.96
# 2023-02-28       3269.60  4060.56
# 2023-03-31       3590.86  7651.42
# Warning: Skipping user 0021 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       1607.65  1607.65
# 2023-02-28        898.68  2506.33
# 2023-03-31        722.40  3228.73
# Warning: Skipping user 0022 due to error: time_col='date' is not present.
#             net_cashflow   balance
# 2023-01-31       3533.36   3533.36
# 2023-02-28       3074.66   6608.02
# 2023-03-31       4115.20  10723.22
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# Warning: Skipping user 0023 due to error: time_col='date' is not present.
#             net_cashflow   balance
# 2023-01-31       2486.44   2486.44
# 2023-02-28       4010.38   6496.82
# 2023-03-31       3670.33  10167.15
# Warning: Skipping user 0024 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       1281.82  1281.82
# 2023-02-28        955.72  2237.54
# 2023-03-31       2270.72  4508.26
# Warning: Skipping user 0025 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       2402.17  2402.17
# 2023-02-28       3383.14  5785.31
# 2023-03-31       1885.44  7670.75
# Warning: Skipping user 0026 due to error: time_col='date' is not present.
#             net_cashflow   balance
# 2023-01-31       3482.06   3482.06
# 2023-02-28       3477.25   6959.31
# 2023-03-31       4863.31  11822.62
# Warning: Skipping user 0027 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       2275.72  2275.72
# 2023-02-28        449.54  2725.26
# 2023-03-31       1094.21  3819.47
# Warning: Skipping user 0028 due to error: time_col='date' is not present.
#             net_cashflow   balance
# 2023-01-31       4301.34   4301.34
# 2023-02-28       3981.65   8282.99
# 2023-03-31       3816.94  12099.93
# Warning: Skipping user 0029 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       2593.54  2593.54
# 2023-02-28       1865.34  4458.88
# 2023-03-31       1100.94  5559.82
# Warning: Skipping user 0030 due to error: time_col='date' is not present.
#             net_cashflow   balance
# 2023-01-31       2365.20   2365.20
# 2023-02-28       5309.11   7674.31
# 2023-03-31       3678.82  11353.13
# Warning: Skipping user 0031 due to error: time_col='date' is not present.
#             net_cashflow   balance
# 2023-01-31       4967.37   4967.37
# 2023-02-28       4735.31   9702.68
# 2023-03-31       5130.05  14832.73
# Warning: Skipping user 0032 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       2613.46  2613.46
# 2023-02-28       2932.70  5546.16
# 2023-03-31       1353.43  6899.59
# Warning: Skipping user 0033 due to error: time_col='date' is not present.
#             net_cashflow   balance
# 2023-01-31       3399.21   3399.21
# 2023-02-28       4175.08   7574.29
# 2023-03-31       3033.02  10607.31
# Warning: Skipping user 0034 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31        380.23   380.23
# 2023-02-28       2412.49  2792.72
# 2023-03-31       2054.42  4847.14
# Warning: Skipping user 0035 due to error: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       1402.01  1402.01
# 2023-02-28       1349.31  2751.32
# 2023-03-31       1860.40  4611.72
# Warning: Skipping user 0036 due to error: time_col='date' is not present.
#             net_cashflow   balance
# 2023-01-31       3292.18   3292.18
# 2023-02-28       4153.79   7445.97
# 2023-03-31       4097.42  11543.39
# Warning: Skipping user 0037 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31        965.09   965.09
# 2023-02-28        863.87  1828.96
# 2023-03-31      -1024.40   804.56
# Warning: Skipping user 0038 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       2842.25  2842.25
# 2023-02-28       2399.13  5241.38
# 2023-03-31       2956.01  8197.39
# Warning: Skipping user 0039 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       2412.50  2412.50
# 2023-02-28       1602.45  4014.95
# 2023-03-31       1317.65  5332.60
# Warning: Skipping user 0040 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       2491.48  2491.48
# 2023-02-28       1129.53  3621.01
# 2023-03-31       -462.64  3158.37
# Warning: Skipping user 0041 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       2103.31  2103.31
# 2023-02-28       2404.03  4507.34
# 2023-03-31       2944.99  7452.33
# Warning: Skipping user 0042 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       -611.48  -611.48
# 2023-02-28        679.39    67.91
# 2023-03-31       1174.43  1242.34
# Warning: Skipping user 0043 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31         84.53    84.53
# 2023-02-28       2013.28  2097.81
# 2023-03-31        975.68  3073.49
# Warning: Skipping user 0044 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       3720.79  3720.79
# 2023-02-28       1229.48  4950.27
# 2023-03-31       2234.02  7184.29
# Warning: Skipping user 0045 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       1242.69  1242.69
# 2023-02-28       1016.28  2258.97
# 2023-03-31        359.57  2618.54
# Warning: Skipping user 0046 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31        618.60   618.60
# 2023-02-28      -1317.07  -698.47
# 2023-03-31        639.61   -58.86
# Warning: Skipping user 0047 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       2750.72  2750.72
# 2023-02-28       3199.95  5950.67
# 2023-03-31       1619.09  7569.76
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# Warning: Skipping user 0048 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31        283.13   283.13
# 2023-02-28        567.48   850.61
# 2023-03-31       1016.60  1867.21
# Warning: Skipping user 0049 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       3189.04  3189.04
# 2023-02-28       2735.28  5924.32
# 2023-03-31       2345.99  8270.31
# Warning: Skipping user 0050 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       2076.63  2076.63
# 2023-02-28        987.18  3063.81
# 2023-03-31       2900.66  5964.47
# Warning: Skipping user 0051 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       3423.50  3423.50
# 2023-02-28       3264.43  6687.93
# 2023-03-31       1678.22  8366.15
# Warning: Skipping user 0052 due to error: time_col='date' is not present.
#             net_cashflow   balance
# 2023-01-31       3697.53   3697.53
# 2023-02-28       3762.46   7459.99
# 2023-03-31       4119.89  11579.88
# Warning: Skipping user 0053 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       1732.36  1732.36
# 2023-02-28       5007.92  6740.28
# 2023-03-31       3192.34  9932.62
# Warning: Skipping user 0054 due to error: time_col='date' is not present.
#             net_cashflow   balance
# 2023-01-31       3188.93   3188.93
# 2023-02-28       3659.19   6848.12
# 2023-03-31       3754.97  10603.09
# Warning: Skipping user 0055 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       1108.71  1108.71
# 2023-02-28       -234.90   873.81
# 2023-03-31       -116.44   757.37
# Warning: Skipping user 0056 due to error: time_col='date' is not present.
#             net_cashflow   balance
# 2023-01-31       3542.29   3542.29
# 2023-02-28       4834.25   8376.54
# 2023-03-31       4293.82  12670.36
# Warning: Skipping user 0057 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       2578.25  2578.25
# 2023-02-28       3241.49  5819.74
# 2023-03-31       2297.35  8117.09
# Warning: Skipping user 0058 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       1961.20  1961.20
# 2023-02-28       1967.68  3928.88
# 2023-03-31       2804.38  6733.26
# Warning: Skipping user 0059 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       2115.15  2115.15
# 2023-02-28       1357.68  3472.83
# 2023-03-31        688.43  4161.26
# Warning: Skipping user 0060 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31        174.43   174.43
# 2023-02-28       1158.01  1332.44
# 2023-03-31       2148.21  3480.65
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# Warning: Skipping user 0061 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       3134.25  3134.25
# 2023-02-28       3811.97  6946.22
# 2023-03-31       2931.90  9878.12
# Warning: Skipping user 0062 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       2011.04  2011.04
# 2023-02-28       1021.13  3032.17
# 2023-03-31       1485.26  4517.43
# Warning: Skipping user 0063 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       3262.26  3262.26
# 2023-02-28       1916.55  5178.81
# 2023-03-31       2412.00  7590.81
# Warning: Skipping user 0064 due to error: time_col='date' is not present.
#             net_cashflow   balance
# 2023-01-31       5123.94   5123.94
# 2023-02-28       5112.45  10236.39
# 2023-03-31       4225.87  14462.26
# Warning: Skipping user 0065 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       2642.20  2642.20
# 2023-02-28       3462.20  6104.40
# 2023-03-31       3627.64  9732.04
# Warning: Skipping user 0066 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       2477.87  2477.87
# 2023-02-28       2087.99  4565.86
# 2023-03-31       2434.89  7000.75
# Warning: Skipping user 0067 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       4300.58  4300.58
# 2023-02-28       1671.99  5972.57
# 2023-03-31       2953.87  8926.44
# Warning: Skipping user 0068 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       -312.75  -312.75
# 2023-02-28       1506.73  1193.98
# 2023-03-31        891.97  2085.95
# Warning: Skipping user 0069 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31      -1077.63 -1077.63
# 2023-02-28        845.36  -232.27
# 2023-03-31        835.57   603.30
# Warning: Skipping user 0070 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       2944.31  2944.31
# 2023-02-28       2278.92  5223.23
# 2023-03-31       1049.29  6272.52
# Warning: Skipping user 0071 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       2576.59  2576.59
# 2023-02-28       2118.04  4694.63
# 2023-03-31        590.83  5285.46
# Warning: Skipping user 0072 due to error: time_col='date' is not present.
#             net_cashflow   balance
# 2023-01-31       4123.63   4123.63
# 2023-02-28       4202.80   8326.43
# 2023-03-31       3566.61  11893.04
# Warning: Skipping user 0073 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       1225.63  1225.63
# 2023-02-28        698.89  1924.52
# 2023-03-31        847.73  2772.25
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# Warning: Skipping user 0074 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       1466.62  1466.62
# 2023-02-28       1315.69  2782.31
# 2023-03-31        149.87  2932.18
# Warning: Skipping user 0075 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       1679.59  1679.59
# 2023-02-28       3010.46  4690.05
# 2023-03-31       3318.53  8008.58
# Warning: Skipping user 0076 due to error: time_col='date' is not present.
#             net_cashflow   balance
# 2023-01-31       3926.84   3926.84
# 2023-02-28       4230.92   8157.76
# 2023-03-31       3364.43  11522.19
# Warning: Skipping user 0077 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       2667.79  2667.79
# 2023-02-28       3083.80  5751.59
# 2023-03-31       3010.56  8762.15
# Warning: Skipping user 0078 due to error: time_col='date' is not present.
#             net_cashflow   balance
# 2023-01-31       5131.91   5131.91
# 2023-02-28       5232.76  10364.67
# 2023-03-31       1989.21  12353.88
# Warning: Skipping user 0079 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       1309.61  1309.61
# 2023-02-28       3318.82  4628.43
# 2023-03-31       1328.84  5957.27
# Warning: Skipping user 0080 due to error: time_col='date' is not present.
#             net_cashflow   balance
# 2023-01-31       3236.38   3236.38
# 2023-02-28       4936.63   8173.01
# 2023-03-31       2685.97  10858.98
# Warning: Skipping user 0081 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       2406.16  2406.16
# 2023-02-28       2546.42  4952.58
# 2023-03-31       1940.83  6893.41
# Warning: Skipping user 0082 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       1236.13  1236.13
# 2023-02-28       2410.88  3647.01
# 2023-03-31       1207.22  4854.23
# Warning: Skipping user 0083 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       2331.39  2331.39
# 2023-02-28       -115.15  2216.24
# 2023-03-31        563.70  2779.94
# Warning: Skipping user 0084 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       1595.07  1595.07
# 2023-02-28       2771.30  4366.37
# 2023-03-31       1963.22  6329.59
# Warning: Skipping user 0085 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       2080.87  2080.87
# 2023-02-28       1339.30  3420.17
# 2023-03-31        938.94  4359.11
# Warning: Skipping user 0086 due to error: time_col='date' is not present.
#             net_cashflow   balance
# 2023-01-31       2843.71   2843.71
# 2023-02-28       6161.09   9004.80
# 2023-03-31       4054.23  13059.03
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# Warning: Skipping user 0087 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       1236.40  1236.40
# 2023-02-28          1.18  1237.58
# 2023-03-31        -15.66  1221.92
# Warning: Skipping user 0088 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       1471.55  1471.55
# 2023-02-28       2330.49  3802.04
# 2023-03-31       1299.23  5101.27
# Warning: Skipping user 0089 due to error: time_col='date' is not present.
#             net_cashflow   balance
# 2023-01-31       3340.50   3340.50
# 2023-02-28       3749.99   7090.49
# 2023-03-31       3967.82  11058.31
# Warning: Skipping user 0090 due to error: time_col='date' is not present.
#             net_cashflow   balance
# 2023-01-31       3465.37   3465.37
# 2023-02-28       3956.43   7421.80
# 2023-03-31       2934.17  10355.97
# Warning: Skipping user 0091 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       2502.52  2502.52
# 2023-02-28       2248.11  4750.63
# 2023-03-31       2198.46  6949.09
# Warning: Skipping user 0092 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       1738.85  1738.85
# 2023-02-28        686.61  2425.46
# 2023-03-31       1161.88  3587.34
# Warning: Skipping user 0093 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       2669.40  2669.40
# 2023-02-28       2309.42  4978.82
# 2023-03-31       2436.90  7415.72
# Warning: Skipping user 0094 due to error: time_col='date' is not present.
#             net_cashflow   balance
# 2023-01-31       3905.31   3905.31
# 2023-02-28       3717.51   7622.82
# 2023-03-31       3247.80  10870.62
# Warning: Skipping user 0095 due to error: time_col='date' is not present.
#             net_cashflow   balance
# 2023-01-31       3434.75   3434.75
# 2023-02-28       3570.14   7004.89
# 2023-03-31       4306.65  11311.54
# Warning: Skipping user 0096 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       2602.57  2602.57
# 2023-02-28       1625.01  4227.58
# 2023-03-31       1925.92  6153.50
# Warning: Skipping user 0097 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       1438.47  1438.47
# 2023-02-28       2913.55  4352.02
# 2023-03-31         68.99  4421.01
# Warning: Skipping user 0098 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       2406.73  2406.73
# 2023-02-28       3687.47  6094.20
# 2023-03-31       3187.99  9282.19
# Warning: Skipping user 0099 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       2634.95  2634.95
# 2023-02-28       1647.83  4282.78
# 2023-03-31       1505.76  5788.54
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# Warning: Skipping user 0100 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31        171.24   171.24
# 2023-02-28       2208.46  2379.70
# 2023-03-31       2312.95  4692.65
# Warning: Skipping user 0101 due to error: time_col='date' is not present.
#             net_cashflow   balance
# 2023-01-31       2894.30   2894.30
# 2023-02-28       3536.81   6431.11
# 2023-03-31       4412.04  10843.15
# Warning: Skipping user 0102 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       1938.06  1938.06
# 2023-02-28       2710.68  4648.74
# 2023-03-31       3127.69  7776.43
# Warning: Skipping user 0103 due to error: time_col='date' is not present.
#             net_cashflow   balance
# 2023-01-31       3254.79   3254.79
# 2023-02-28       4273.52   7528.31
# 2023-03-31       3803.66  11331.97
# Warning: Skipping user 0104 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       1244.55  1244.55
# 2023-02-28       2166.15  3410.70
# 2023-03-31      -1300.97  2109.73
# Warning: Skipping user 0105 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       3453.75  3453.75
# 2023-02-28       2654.88  6108.63
# 2023-03-31       2855.35  8963.98
# Warning: Skipping user 0106 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       1885.40  1885.40
# 2023-02-28       1697.51  3582.91
# 2023-03-31       2113.25  5696.16
# Warning: Skipping user 0107 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       1455.42  1455.42
# 2023-02-28       1542.74  2998.16
# 2023-03-31       2032.36  5030.52
# Warning: Skipping user 0108 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       3177.61  3177.61
# 2023-02-28       2036.07  5213.68
# 2023-03-31       1449.57  6663.25
# Warning: Skipping user 0109 due to error: time_col='date' is not present.
#             net_cashflow   balance
# 2023-01-31       3401.50   3401.50
# 2023-02-28       4132.35   7533.85
# 2023-03-31       3134.54  10668.39
# Warning: Skipping user 0110 due to error: time_col='date' is not present.
#             net_cashflow   balance
# 2023-01-31       4364.69   4364.69
# 2023-02-28       3846.73   8211.42
# 2023-03-31       3577.09  11788.51
# Warning: Skipping user 0111 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31        595.14   595.14
# 2023-02-28       1172.99  1768.13
# 2023-03-31       1245.38  3013.51
# Warning: Skipping user 0112 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31        534.56   534.56
# 2023-02-28        231.84   766.40
# 2023-03-31        987.92  1754.32
# Warning: Skipping user 0113 due to error: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       1334.40  1334.40
# 2023-02-28        326.42  1660.82
# 2023-03-31        765.25  2426.07
# Warning: Skipping user 0114 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31        553.58   553.58
# 2023-02-28         56.85   610.43
# 2023-03-31        757.32  1367.75
# Warning: Skipping user 0115 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       2226.14  2226.14
# 2023-02-28       1214.90  3441.04
# 2023-03-31       1249.11  4690.15
# Warning: Skipping user 0116 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31        336.12   336.12
# 2023-02-28       1404.61  1740.73
# 2023-03-31        755.27  2496.00
# Warning: Skipping user 0117 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       1723.09  1723.09
# 2023-02-28       1244.01  2967.10
# 2023-03-31        361.46  3328.56
# Warning: Skipping user 0118 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       1302.03  1302.03
# 2023-02-28       1390.80  2692.83
# 2023-03-31       -402.72  2290.11
# Warning: Skipping user 0119 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       2342.67  2342.67
# 2023-02-28       1608.93  3951.60
# 2023-03-31       1317.05  5268.65
# Warning: Skipping user 0120 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       2442.20  2442.20
# 2023-02-28       1358.51  3800.71
# 2023-03-31        323.41  4124.12
# Warning: Skipping user 0121 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       3072.50  3072.50
# 2023-02-28       3069.78  6142.28
# 2023-03-31       2950.66  9092.94
# Warning: Skipping user 0122 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       1962.08  1962.08
# 2023-02-28       1928.57  3890.65
# 2023-03-31       1827.26  5717.91
# Warning: Skipping user 0123 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       1553.09  1553.09
# 2023-02-28       1731.35  3284.44
# 2023-03-31       1640.01  4924.45
# Warning: Skipping user 0124 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       1361.86  1361.86
# 2023-02-28       2398.58  3760.44
# 2023-03-31       2571.66  6332.10
# Warning: Skipping user 0125 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       2226.18  2226.18
# 2023-02-28       2695.60  4921.78
# 2023-03-31       2991.58  7913.36
# Warning: Skipping user 0126 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       1887.27  1887.27
# 2023-02-28        881.25  2768.52
# 2023-03-31       1726.49  4495.01
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# Warning: Skipping user 0127 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       1395.61  1395.61
# 2023-02-28       2956.95  4352.56
# 2023-03-31       3747.72  8100.28
# Warning: Skipping user 0128 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31        859.81   859.81
# 2023-02-28        668.31  1528.12
# 2023-03-31        944.63  2472.75
# Warning: Skipping user 0129 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       2225.46  2225.46
# 2023-02-28        894.25  3119.71
# 2023-03-31       2910.03  6029.74
# Warning: Skipping user 0130 due to error: time_col='date' is not present.
#             net_cashflow   balance
# 2023-01-31       3334.50   3334.50
# 2023-02-28       3730.08   7064.58
# 2023-03-31       4067.72  11132.30
# Warning: Skipping user 0131 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       1819.95  1819.95
# 2023-02-28       1461.80  3281.75
# 2023-03-31        882.77  4164.52
# Warning: Skipping user 0132 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       2573.59  2573.59
# 2023-02-28       3837.59  6411.18
# 2023-03-31       2264.15  8675.33
# Warning: Skipping user 0133 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       3008.51  3008.51
# 2023-02-28       2756.48  5764.99
# 2023-03-31        907.69  6672.68
# Warning: Skipping user 0134 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       3156.42  3156.42
# 2023-02-28       1454.79  4611.21
# 2023-03-31       3616.70  8227.91
# Warning: Skipping user 0135 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       1246.34  1246.34
# 2023-02-28       1171.92  2418.26
# 2023-03-31        543.96  2962.22
# Warning: Skipping user 0136 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       1233.01  1233.01
# 2023-02-28       2504.17  3737.18
# 2023-03-31       2390.85  6128.03
# Warning: Skipping user 0137 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       3133.80  3133.80
# 2023-02-28       2521.96  5655.76
# 2023-03-31       1936.49  7592.25
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# Warning: Skipping user 0138 due to error: time_col='date' is not present.
#             net_cashflow   balance
# 2023-01-31       3873.00   3873.00
# 2023-02-28       3510.39   7383.39
# 2023-03-31       2939.35  10322.74
# Warning: Skipping user 0139 due to error: time_col='date' is not present.
#             net_cashflow   balance
# 2023-01-31       4224.73   4224.73
# 2023-02-28       2947.39   7172.12
# 2023-03-31       3765.36  10937.48
# Warning: Skipping user 0140 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       3185.17  3185.17
# 2023-02-28       2869.71  6054.88
# 2023-03-31       3498.88  9553.76
# Warning: Skipping user 0141 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       2367.72  2367.72
# 2023-02-28       3659.21  6026.93
# 2023-03-31       2826.69  8853.62
# Warning: Skipping user 0142 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       2922.13  2922.13
# 2023-02-28       3056.52  5978.65
# 2023-03-31       2589.04  8567.69
# Warning: Skipping user 0143 due to error: time_col='date' is not present.
#             net_cashflow   balance
# 2023-01-31       3916.04   3916.04
# 2023-02-28       3421.38   7337.42
# 2023-03-31       2777.19  10114.61
# Warning: Skipping user 0144 due to error: time_col='date' is not present.
#             net_cashflow   balance
# 2023-01-31       4388.56   4388.56
# 2023-02-28       4518.13   8906.69
# 2023-03-31       3955.59  12862.28
# Warning: Skipping user 0145 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       1164.01  1164.01
# 2023-02-28        721.87  1885.88
# 2023-03-31        559.39  2445.27
# Warning: Skipping user 0146 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       1621.47  1621.47
# 2023-02-28       2583.96  4205.43
# 2023-03-31       2051.96  6257.39
# Warning: Skipping user 0147 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       1648.86  1648.86
# 2023-02-28       2151.65  3800.51
# 2023-03-31      -1880.79  1919.72
# Warning: Skipping user 0148 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       2851.95  2851.95
# 2023-02-28       3531.72  6383.67
# 2023-03-31       2267.02  8650.69
# Warning: Skipping user 0149 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       1141.49  1141.49
# 2023-02-28       2097.33  3238.82
# 2023-03-31        810.96  4049.78
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# Warning: Skipping user 0150 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       1594.64  1594.64
# 2023-02-28       2339.63  3934.27
# 2023-03-31       1386.26  5320.53
# Warning: Skipping user 0151 due to error: time_col='date' is not present.
#             net_cashflow   balance
# 2023-01-31       4341.54   4341.54
# 2023-02-28       4223.50   8565.04
# 2023-03-31       4336.57  12901.61
# Warning: Skipping user 0152 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31         69.77    69.77
# 2023-02-28       -846.49  -776.72
# 2023-03-31        773.05    -3.67
# Warning: Skipping user 0153 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       2796.22  2796.22
# 2023-02-28       2440.02  5236.24
# 2023-03-31       2302.62  7538.86
# Warning: Skipping user 0154 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31        865.59   865.59
# 2023-02-28       3458.07  4323.66
# 2023-03-31       2714.79  7038.45
# Warning: Skipping user 0155 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31        837.62   837.62
# 2023-02-28        518.26  1355.88
# 2023-03-31        336.15  1692.03
# Warning: Skipping user 0156 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       2711.47  2711.47
# 2023-02-28       3843.03  6554.50
# 2023-03-31       2638.06  9192.56
# Warning: Skipping user 0157 due to error: time_col='date' is not present.
#             net_cashflow   balance
# 2023-01-31       3652.73   3652.73
# 2023-02-28       4245.11   7897.84
# 2023-03-31       3461.48  11359.32
# Warning: Skipping user 0158 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       3137.50  3137.50
# 2023-02-28       1823.93  4961.43
# 2023-03-31       1332.85  6294.28
# Warning: Skipping user 0159 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       3067.25  3067.25
# 2023-02-28       3263.65  6330.90
# 2023-03-31       1511.61  7842.51
# Warning: Skipping user 0160 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       2286.99  2286.99
# 2023-02-28       1796.40  4083.39
# 2023-03-31       1290.51  5373.90
# Warning: Skipping user 0161 due to error: time_col='date' is not present.
#             net_cashflow   balance
# 2023-01-31       3930.52   3930.52
# 2023-02-28       5109.21   9039.73
# 2023-03-31       4556.29  13596.02
# Warning: Skipping user 0162 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       2009.12  2009.12
# 2023-02-28        623.91  2633.03
# 2023-03-31       1837.99  4471.02
# Warning: Skipping user 0163 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       1405.35  1405.35
# 2023-02-28       1462.59  2867.94
# 2023-03-31       -260.48  2607.46
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# Warning: Skipping user 0164 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       3298.28  3298.28
# 2023-02-28       1609.66  4907.94
# 2023-03-31       2700.26  7608.20
# Warning: Skipping user 0165 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       1993.55  1993.55
# 2023-02-28       3374.40  5367.95
# 2023-03-31       4071.81  9439.76
# Warning: Skipping user 0166 due to error: time_col='date' is not present.
#             net_cashflow   balance
# 2023-01-31       2727.65   2727.65
# 2023-02-28       4011.26   6738.91
# 2023-03-31       3817.61  10556.52
# Warning: Skipping user 0167 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31        798.50   798.50
# 2023-02-28       -160.26   638.24
# 2023-03-31        -33.93   604.31
# Warning: Skipping user 0168 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       1301.35  1301.35
# 2023-02-28       2526.93  3828.28
# 2023-03-31        976.88  4805.16
# Warning: Skipping user 0169 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       1287.15  1287.15
# 2023-02-28       2687.46  3974.61
# 2023-03-31       1089.07  5063.68
# Warning: Skipping user 0170 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       1862.68  1862.68
# 2023-02-28       3954.43  5817.11
# 2023-03-31       2159.74  7976.85
# Warning: Skipping user 0171 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       4258.70  4258.70
# 2023-02-28       2928.12  7186.82
# 2023-03-31       2379.30  9566.12
# Warning: Skipping user 0172 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31        439.70   439.70
# 2023-02-28       2362.27  2801.97
# 2023-03-31       1508.05  4310.02
# Warning: Skipping user 0173 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       -876.89  -876.89
# 2023-02-28       1865.05   988.16
# 2023-03-31        886.20  1874.36
# Warning: Skipping user 0174 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       1486.93  1486.93
# 2023-02-28       1138.90  2625.83
# 2023-03-31       1643.85  4269.68
# Warning: Skipping user 0175 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       3007.13  3007.13
# 2023-02-28       2821.37  5828.50
# 2023-03-31       2420.66  8249.16
# Warning: Skipping user 0176 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31        550.85   550.85
# 2023-02-28       1195.68  1746.53
# 2023-03-31       1523.15  3269.68
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# Warning: Skipping user 0177 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       2816.52  2816.52
# 2023-02-28       3929.98  6746.50
# 2023-03-31       2484.84  9231.34
# Warning: Skipping user 0178 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       1080.37  1080.37
# 2023-02-28       1412.66  2493.03
# 2023-03-31        -82.49  2410.54
# Warning: Skipping user 0179 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       2270.84  2270.84
# 2023-02-28       1729.37  4000.21
# 2023-03-31       2696.68  6696.89
# Warning: Skipping user 0180 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31        392.61   392.61
# 2023-02-28       -133.74   258.87
# 2023-03-31       -373.26  -114.39
# Warning: Skipping user 0181 due to error: time_col='date' is not present.
#             net_cashflow   balance
# 2023-01-31       3767.48   3767.48
# 2023-02-28       4629.26   8396.74
# 2023-03-31       5111.36  13508.10
# Warning: Skipping user 0182 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       1049.26  1049.26
# 2023-02-28       2664.68  3713.94
# 2023-03-31        989.28  4703.22
# Warning: Skipping user 0183 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31        401.19   401.19
# 2023-02-28        809.91  1211.10
# 2023-03-31        309.20  1520.30
# Warning: Skipping user 0184 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       -458.84  -458.84
# 2023-02-28       1961.83  1502.99
# 2023-03-31        225.73  1728.72
# Warning: Skipping user 0185 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31          2.35     2.35
# 2023-02-28        348.22   350.57
# 2023-03-31        311.31   661.88
# Warning: Skipping user 0186 due to error: time_col='date' is not present.
#             net_cashflow   balance
# 2023-01-31       5242.09   5242.09
# 2023-02-28       5463.85  10705.94
# 2023-03-31       3992.65  14698.59
# Warning: Skipping user 0187 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       -257.94  -257.94
# 2023-02-28       3924.96  3667.02
# 2023-03-31       1877.55  5544.57
# Warning: Skipping user 0188 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       -213.78  -213.78
# 2023-02-28        597.68   383.90
# 2023-03-31        811.02  1194.92
# Warning: Skipping user 0189 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31        677.08   677.08
# 2023-02-28       1555.92  2233.00
# 2023-03-31       -547.73  1685.27
# Warning: Skipping user 0190 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       3189.62  3189.62
# 2023-02-28       2869.12  6058.74
# 2023-03-31       3176.65  9235.39
# AttributeError: time_col='date' is not present.
# AttributeError: time_col='date' is not present.
# Warning: Skipping user 0191 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       2119.22  2119.22
# 2023-02-28       1263.02  3382.24
# 2023-03-31       2182.63  5564.87
# Warning: Skipping user 0192 due to error: time_col='date' is not present.
#             net_cashflow  balance
# 2023-01-31       2557.75  2557.75
# 2023-02-28       2759.98  5317.73
# 2023-03-31       1989.38  7307.11
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[41], line 2
#       1 if __name__ == '__main__':
# ----> 2     main()
#
# Cell In[36], line 13, in main()
#      11 # Build datasets
#      12 print("\n1. Building datasets...")
# ---> 13 datasets = build_datasets(DATA_DIR, holdout_frac=0.1, min_months=3, seed=42)
#      15 if not datasets['train_series']:
#      16     raise RuntimeError("No valid training data found")
#
# Cell In[39], line 165, in build_datasets(data_dir, holdout_frac, min_months, seed)
#     163 print(monthly_features)
#     164 # Create TimeSeries for both features
# --> 165 ts_data = TimeSeries.from_dataframe(
#     166     monthly_features.reset_index(),
#     167     time_col='date',
#     168     value_cols=['net_cashflow', 'balance']
#     169 )
#     171 user_type = 'seen' if user_id in seen_users else 'unseen'
#     172 datasets['real_series'][user_type].append(ts_data)
#
# File c:\Users\idanh\OneDrive - Technion\GenAI\Local Code\venv\Lib\site-packages\darts\timeseries.py:815, in TimeSeries.from_dataframe(cls, df, time_col, value_cols, fill_missing_dates, freq, fillna_value, static_covariates, hierarchy, metadata, copy)
#     813 if time_col:
#     814     if time_col not in df.columns:
# --> 815         raise_log(AttributeError(f"time_col='{time_col}' is not present."))
#     817     time_col_vals = df.get_column(time_col)
#     819     if time_col_vals.dtype == nw.String:
#     820         # Try to convert to integers if needed
#
# File c:\Users\idanh\OneDrive - Technion\GenAI\Local Code\venv\Lib\site-packages\darts\logging.py:130, in raise_log(exception, logger)
#     128 exception_type = str(type(exception)).split("'")[1]
#     129 message = str(exception)
# --> 130 logger.error(exception_type + ": " + message)
#     132 raise exception
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\logging\__init__.py:1518, in Logger.error(self, msg, *args, **kwargs)
#    1509 """
#    1510 Log 'msg % args' with severity 'ERROR'.
#    1511
#    (...)   1515 logger.error("Houston, we have a %s", "major problem", exc_info=1)
#    1516 """
#    1517 if self.isEnabledFor(ERROR):
# -> 1518     self._log(ERROR, msg, args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\logging\__init__.py:1634, in Logger._log(self, level, msg, args, exc_info, extra, stack_info, stacklevel)
#    1631         exc_info = sys.exc_info()
#    1632 record = self.makeRecord(self.name, level, fn, lno, msg, args,
#    1633                          exc_info, func, extra, sinfo)
# -> 1634 self.handle(record)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\logging\__init__.py:1644, in Logger.handle(self, record)
#    1637 """
#    1638 Call the handlers for the specified record.
#    1639
#    1640 This method is used for unpickled records received from a socket, as
#    1641 well as those created locally. Logger-level filtering is applied.
#    1642 """
#    1643 if (not self.disabled) and self.filter(record):
# -> 1644     self.callHandlers(record)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\logging\__init__.py:1714, in Logger.callHandlers(self, record)
#    1712 if lastResort:
#    1713     if record.levelno >= lastResort.level:
# -> 1714         lastResort.handle(record)
#    1715 elif raiseExceptions and not self.manager.emittedNoHandlerWarning:
#    1716     sys.stderr.write("No handlers could be found for logger"
#    1717                      " \"%s\"\n" % self.name)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\logging\__init__.py:978, in Handler.handle(self, record)
#     976 self.acquire()
#     977 try:
# --> 978     self.emit(record)
#     979 finally:
#     980     self.release()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\logging\__init__.py:1113, in StreamHandler.emit(self, record)
#    1111     stream = self.stream
#    1112     # issue 35046: merged two stream.writes into one.
# -> 1113     stream.write(msg + self.terminator)
#    1114     self.flush()
#    1115 except RecursionError:  # See issue 36272
#
# File c:\Users\idanh\OneDrive - Technion\GenAI\Local Code\venv\Lib\site-packages\IPython\core\interactiveshell.py:3045, in InteractiveShell._tee.<locals>.write(data, *args, **kwargs)
#    3043 def write(data, *args, **kwargs):
#    3044     """Write data to both the original destination and the capture dictionary."""
# -> 3045     result = original_write(data, *args, **kwargs)
#    3046     if any(
#    3047         [
#    3048             self.display_pub.is_publishing,
#    (...)   3051         ]
#    3052     ):
#    3053         return result
#
# File c:\Users\idanh\OneDrive - Technion\GenAI\Local Code\venv\Lib\site-packages\ipykernel\iostream.py:694, in OutStream.write(self, string)
#     692     self.pub_thread.schedule(self._flush)
#     693 else:
# --> 694     self._schedule_flush()
#     696 return len(string)
#
# File c:\Users\idanh\OneDrive - Technion\GenAI\Local Code\venv\Lib\site-packages\ipykernel\iostream.py:590, in OutStream._schedule_flush(self)
#     587 def _schedule_in_thread():
#     588     self._io_loop.call_later(self.flush_interval, self._flush)
# --> 590 self.pub_thread.schedule(_schedule_in_thread)
#
# File c:\Users\idanh\OneDrive - Technion\GenAI\Local Code\venv\Lib\site-packages\ipykernel\iostream.py:267, in IOPubThread.schedule(self, f)
#     265     self._events.append(f)
#     266     # wake event thread (message content is ignored)
# --> 267     self._event_pipe.send(b"")
#     268 else:
#     269     f()
#
# File c:\Users\idanh\OneDrive - Technion\GenAI\Local Code\venv\Lib\site-packages\zmq\sugar\socket.py:698, in Socket.send(self, data, flags, copy, track, routing_id, group)
#     691         data = zmq.Frame(
#     692             data,
#     693             track=track,
#     694             copy=copy or None,
#     695             copy_threshold=self.copy_threshold,
#     696         )
#     697     data.group = group
# --> 698 return super().send(data, flags=flags, copy=copy, track=track)
#
# File c:\Users\idanh\OneDrive - Technion\GenAI\Local Code\venv\Lib\site-packages\zmq\backend\cython\_zmq.py:1137, in zmq.backend.cython._zmq.Socket.send()
#
# File c:\Users\idanh\OneDrive - Technion\GenAI\Local Code\venv\Lib\site-packages\zmq\backend\cython\_zmq.py:1185, in zmq.backend.cython._zmq.Socket.send()
#
# File c:\Users\idanh\OneDrive - Technion\GenAI\Local Code\venv\Lib\site-packages\zmq\backend\cython\_zmq.py:1453, in zmq.backend.cython._zmq._send_copy()
#
# File c:\Users\idanh\OneDrive - Technion\GenAI\Local Code\venv\Lib\site-packages\zmq\backend\cython\_zmq.py:176, in zmq.backend.cython._zmq._check_rc()
#
# KeyboardInterrupt:
